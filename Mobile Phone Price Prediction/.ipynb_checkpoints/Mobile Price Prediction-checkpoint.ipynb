# %%
#Install libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# % matplotlib inline

#Import dataset
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
test.head(10)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
# 5   6           1464     1          2.9         1   5       1          50
# 6   7           1718     0          2.4         0   1       0          47
# 7   8            833     0          2.4         1   0       0          62
# 8   9           1111     1          2.9         1   9       1          25
# 9  10           1520     0          0.5         0   1       0          25
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# ...

# %% [markdown]
# ## Predicting Values for train dataset

# %%
train.shape
# Out:
# (2000, 21)

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#Plot heatmap

plt.figure(figsize = (12,6))
sns.heatmap(train.corr())
plt.show()

# %%
#Pot relation between price_range and battery_power

plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range', y = 'battery_power', data = train)
plt.show()

# %%
#Plot relation between price_range and px_height,px_width

plt.figure(figsize = (14,6))
plt.subplot(1,2,1)
sns.barplot(x = 'price_range', y = 'px_height', data = train, palette = 'Greens')
plt.subplot(1,2,2)
sns.barplot(x = 'price_range', y = 'px_width', data = train, palette = 'Reds')
plt.show()

# %%
# Plot price_range against ram

plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range', y = 'ram', data = train, palette = 'Blues')
plt.show()

# %%
#plot 3g with price_range

plt.figure(figsize = (12,6))
sns.countplot(train['three_g'], hue = train['price_range'], data = train)
plt.show()
# Out:
# C:\Users\PHANEROO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plot 4g with price_range

plt.figure(figsize = (12,6))
sns.countplot(train['four_g'], hue = train['price_range'], data = train)
plt.show()
# Out:
# C:\Users\PHANEROO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plot relation between price_range and memory

plt.figure(figsize = (12,6))
sns.lineplot(x = 'price_range', y = 'int_memory', data = train, hue = 'dual_sim')
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
x = train.drop(['price_range'], axis = 1)
y = train['price_range']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %% [markdown]
# ## KNN Prediction

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(x_train, y_train)
# Out:
# 0.9457142857142857

# %%
predictions = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 0.935

# %% [markdown]
# ## Predicting values for test dataset

# %%
test.shape
# Out:
# (1000, 21)

# %%
test = test.drop(['id'], axis = 1)
test.shape
# Out:
# (1000, 20)

# %%
pred_test = knn.predict(test)
test['predicted_price'] = pred_test

# %%
test.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
# 5           1464     1          2.9         1   5       1          50    0.8
# 6           1718     0          2.4         0   1       0          47    1.0
# 7            833     0          2.4         1   0       0          62    0.8
# 8           1111     1          2.9         1   9       1          25    0.6
# 9           1520     0          0.5         0   1       0          25    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...
